# %% [markdown]
# <a href="https://colab.research.google.com/github/fherdy/Andriod-App-Store-Data/blob/main/Android_App_Store_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Number of rows and columns
app_df = pd.read_csv('apps.csv')
app_df.shape
# Out:
# (10841, 12)

# %%
app_df.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0       8.7        0  Paid  $13.99           Teen           Social
# 1        0      33.0        0  Paid   $2.99       Everyone        Education
# 2        0       5.5        0  Paid   $1.49       Everyone  Personalization
# 3        0      19.0        0   NaN       0   Everyone 10+         Strategy
# 4        0      10.0        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# ...

# %%
app_df.sample(10)
# Out:
#                                          App             Category  Rating  \
# 301                              FK Vozdovac               SPORTS     NaN
# 7606                【Miku AR Camera】Mikuture               FAMILY     4.4
# 7954                             Bloons TD 5               FAMILY     4.6
# 6310                           Monica Toy TV               FAMILY     4.7
# 6759               Golden Dictionary (EN-AR)  BOOKS_AND_REFERENCE     4.4
# 9054                      Puffin Web Browser        COMMUNICATION     4.3
# 6670                 Vuze Torrent Downloader        VIDEO_PLAYERS     4.1
# 899                            FD Fotografia          PHOTOGRAPHY     NaN
# 10802          Skype - free IM & video calls        COMMUNICATION     4.1
# 6804   JotterPad - Writer, Screenplay, Novel         PRODUCTIVITY     4.6
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating  \
# 301           1      26.0             10  Free      0       Everyone
# ...

# %%
#Remove columns Last_Updated and Andriod_Version
clean_app_df = app_df.drop(['Last_Updated', 'Android_Ver'], axis=1)
clean_app_df.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0       8.7        0  Paid  $13.99           Teen           Social
# 1        0      33.0        0  Paid   $2.99       Everyone        Education
# 2        0       5.5        0  Paid   $1.49       Everyone  Personalization
# 3        0      19.0        0   NaN       0   Everyone 10+         Strategy
# 4        0      10.0        0  Free       0       Everyone         Business
